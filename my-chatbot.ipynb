# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.layers import TextVectorization
import re,string
from tensorflow.keras.layers import LSTM,Dense,Embedding,Dropout,LayerNormalization

# %%
df=pd.read_csv('/kaggle/input/simple-dialogs-for-chatbot/dialogs.txt',sep='\t',names=['question','answer'])
print(f'Dataframe size: {len(df)}')
df.head()
# Out:
# Dataframe size: 3725
#                               question  \
# 0               hi, how are you doing?
# 1        i'm fine. how about yourself?
# 2  i'm pretty good. thanks for asking.
# 3    no problem. so how have you been?
# 4     i've been great. what about you?
#
#                                      answer
# 0             i'm fine. how about yourself?
# 1       i'm pretty good. thanks for asking.
# 2         no problem. so how have you been?
# 3          i've been great. what about you?
# 4  i've been good. i'm in school right now.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data Visualization

# %%
df['question tokens']=df['question'].apply(lambda x:len(x.split()))
df['answer tokens']=df['answer'].apply(lambda x:len(x.split()))
plt.style.use('fivethirtyeight')
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
sns.set_palette('Set2')
sns.histplot(x=df['question tokens'],data=df,kde=True,ax=ax[0])
sns.histplot(x=df['answer tokens'],data=df,kde=True,ax=ax[1])
sns.jointplot(x='question tokens',y='answer tokens',data=df,kind='kde',fill=True,cmap='YlGnBu')
plt.show()

# %% [markdown]
# ## Text Cleaning

# %%
def clean_text(text):
    text=re.sub('-',' ',text.lower())
    text=re.sub('[.]',' . ',text)
    text=re.sub('[1]',' 1 ',text)
    text=re.sub('[2]',' 2 ',text)
    text=re.sub('[3]',' 3 ',text)
    text=re.sub('[4]',' 4 ',text)
    text=re.sub('[5]',' 5 ',text)
    text=re.sub('[6]',' 6 ',text)
    text=re.sub('[7]',' 7 ',text)
    text=re.sub('[8]',' 8 ',text)
    text=re.sub('[9]',' 9 ',text)
    text=re.sub('[0]',' 0 ',text)
    text=re.sub('[,]',' , ',text)
    text=re.sub('[?]',' ? ',text)
    text=re.sub('[!]',' ! ',text)
    text=re.sub('[$]',' $ ',text)
    text=re.sub('[&]',' & ',text)
    text=re.sub('[/]',' / ',text)
    text=re.sub('[:]',' : ',text)
    text=re.sub('[;]',' ; ',text)
    text=re.sub('[*]',' * ',text)
    text=re.sub('[\']',' \' ',text)
    text=re.sub('[\"]',' \" ',text)
    text=re.sub('\t',' ',text)
    return text

df.drop(columns=['answer tokens','question tokens'],axis=1,inplace=True)
df['encoder_inputs']=df['question'].apply(clean_text)
df['decoder_targets']=df['answer'].apply(clean_text)+' <end>'
df['decoder_inputs']='<start> '+df['answer'].apply(clean_text)+' <end>'

df.head(10)
# Out:
#                                    question  \
# 0                    hi, how are you doing?
# 1             i'm fine. how about yourself?
# 2       i'm pretty good. thanks for asking.
# 3         no problem. so how have you been?
# 4          i've been great. what about you?
# 5  i've been good. i'm in school right now.
# 6                 what school do you go to?
# 7                              i go to pcc.
# 8                     do you like it there?
# 9      it's okay. it's a really big campus.
#
#                                      answer  \
# 0             i'm fine. how about yourself?
# 1       i'm pretty good. thanks for asking.
# 2         no problem. so how have you been?
# 3          i've been great. what about you?
# 4  i've been good. i'm in school right now.
# 5                 what school do you go to?
# 6                              i go to pcc.
# 7                     do you like it there?
# 8      it's okay. it's a really big campus.
# 9                    good luck with school.
#
#                                      encoder_inputs  \
# 0                        hi ,  how are you doing ?
# 1               i ' m fine .  how about yourself ?
# 2         i ' m pretty good .  thanks for asking .
# 3             no problem .  so how have you been ?
# 4            i ' ve been great .  what about you ?
# 5  i ' ve been good .  i ' m in school right now .
# 6                       what school do you go to ?
# 7                                    i go to pcc .
# 8                           do you like it there ?
# 9      it ' s okay .  it ' s a really big campus .
#
#                                      decoder_targets  \
# 0          i ' m fine .  how about yourself ?  <end>
# 1    i ' m pretty good .  thanks for asking .  <end>
# 2        no problem .  so how have you been ?  <end>
# 3       i ' ve been great .  what about you ?  <end>
# 4  i ' ve been good .  i ' m in school right now ...
# 5                  what school do you go to ?  <end>
# 6                               i go to pcc .  <end>
# 7                      do you like it there ?  <end>
# 8  it ' s okay .  it ' s a really big campus .  <...
# 9                     good luck with school .  <end>
#
#                                       decoder_inputs
# 0  <start> i ' m fine .  how about yourself ?  <end>
# 1  <start> i ' m pretty good .  thanks for asking...
# 2  <start> no problem .  so how have you been ?  ...
# 3  <start> i ' ve been great .  what about you ? ...
# 4  <start> i ' ve been good .  i ' m in school ri...
# 5          <start> what school do you go to ?  <end>
# 6                       <start> i go to pcc .  <end>
# 7              <start> do you like it there ?  <end>
# 8  <start> it ' s okay .  it ' s a really big cam...
# 9             <start> good luck with school .  <end>

# %%
df['encoder input tokens']=df['encoder_inputs'].apply(lambda x:len(x.split()))
df['decoder input tokens']=df['decoder_inputs'].apply(lambda x:len(x.split()))
df['decoder target tokens']=df['decoder_targets'].apply(lambda x:len(x.split()))
plt.style.use('fivethirtyeight')
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(20,5))
sns.set_palette('Set2')
sns.histplot(x=df['encoder input tokens'],data=df,kde=True,ax=ax[0])
sns.histplot(x=df['decoder input tokens'],data=df,kde=True,ax=ax[1])
sns.histplot(x=df['decoder target tokens'],data=df,kde=True,ax=ax[2])
sns.jointplot(x='encoder input tokens',y='decoder target tokens',data=df,kind='kde',fill=True,cmap='YlGnBu')
plt.show()

# %%
print(f"After preprocessing: {' '.join(df[df['encoder input tokens'].max()==df['encoder input tokens']]['encoder_inputs'].values.tolist())}")
print(f"Max encoder input length: {df['encoder input tokens'].max()}")
print(f"Max decoder input length: {df['decoder input tokens'].max()}")
print(f"Max decoder target length: {df['decoder target tokens'].max()}")

df.drop(columns=['question','answer','encoder input tokens','decoder input tokens','decoder target tokens'],axis=1,inplace=True)
params={
    "vocab_size":2500,
    "max_sequence_length":30,
    "learning_rate":0.008,
    "batch_size":149,
    "lstm_cells":256,
    "embedding_dim":256,
    "buffer_size":10000
}
learning_rate=params['learning_rate']
batch_size=params['batch_size']
embedding_dim=params['embedding_dim']
lstm_cells=params['lstm_cells']
vocab_size=params['vocab_size']
buffer_size=params['buffer_size']
max_sequence_length=params['max_sequence_length']
df.head(10)
# Out:
# After preprocessing: for example ,  if your birth date is january  1  2  ,   1  9  8  7  ,  write  0  1  /  1  2  /  8  7  .
# Max encoder input length: 27
# Max decoder input length: 29
# Max decoder target length: 28
#                                      encoder_inputs  \
# 0                        hi ,  how are you doing ?
# 1               i ' m fine .  how about yourself ?
# 2         i ' m pretty good .  thanks for asking .
# 3             no problem .  so how have you been ?
# 4            i ' ve been great .  what about you ?
# 5  i ' ve been good .  i ' m in school right now .
# 6                       what school do you go to ?
# 7                                    i go to pcc .
# 8                           do you like it there ?
# 9      it ' s okay .  it ' s a really big campus .
#
#                                      decoder_targets  \
# 0          i ' m fine .  how about yourself ?  <end>
# 1    i ' m pretty good .  thanks for asking .  <end>
# 2        no problem .  so how have you been ?  <end>
# 3       i ' ve been great .  what about you ?  <end>
# 4  i ' ve been good .  i ' m in school right now ...
# 5                  what school do you go to ?  <end>
# 6                               i go to pcc .  <end>
# 7                      do you like it there ?  <end>
# 8  it ' s okay .  it ' s a really big campus .  <...
# 9                     good luck with school .  <end>
#
#                                       decoder_inputs
# 0  <start> i ' m fine .  how about yourself ?  <end>
# 1  <start> i ' m pretty good .  thanks for asking...
# 2  <start> no problem .  so how have you been ?  ...
# 3  <start> i ' ve been great .  what about you ? ...
# 4  <start> i ' ve been good .  i ' m in school ri...
# 5          <start> what school do you go to ?  <end>
# 6                       <start> i go to pcc .  <end>
# 7              <start> do you like it there ?  <end>
# 8  <start> it ' s okay .  it ' s a really big cam...
# 9             <start> good luck with school .  <end>

# %% [markdown]
# ## Tokenization

# %%
vectorize_layer=TextVectorization(
    max_tokens=vocab_size,
    standardize=None,
    output_mode='int',
    output_sequence_length=max_sequence_length
)
vectorize_layer.adapt(df['encoder_inputs']+' '+df['decoder_targets']+' <start> <end>')
vocab_size=len(vectorize_layer.get_vocabulary())
print(f'Vocab size: {len(vectorize_layer.get_vocabulary())}')
print(f'{vectorize_layer.get_vocabulary()[:12]}')
# Out:
# Vocab size: 2443
# ['', '[UNK]', '<end>', '.', '<start>', "'", 'i', '?', 'you', ',', 'the', 'to']

# %%
def sequences2ids(sequence):
    return vectorize_layer(sequence)

def ids2sequences(ids):
    decode=''
    if type(ids)==int:
        ids=[ids]
    for id in ids:
        decode+=vectorize_layer.get_vocabulary()[id]+' '
    return decode

x=sequences2ids(df['encoder_inputs'])
yd=sequences2ids(df['decoder_inputs'])
y=sequences2ids(df['decoder_targets'])

print(f'Question sentence: hi , how are you ?')
print(f'Question to tokens: {sequences2ids("hi , how are you ?")[:10]}')
print(f'Encoder input shape: {x.shape}')
print(f'Decoder input shape: {yd.shape}')
print(f'Decoder target shape: {y.shape}')
# Out:
# Question sentence: hi , how are you ?
# Question to tokens: [1971    9   45   24    8    7    0    0    0    0]
# Encoder input shape: (3725, 30)
# Decoder input shape: (3725, 30)
# Decoder target shape: (3725, 30)

# %%
print(f'Encoder input: {x[0][:12]} ...')
print(f'Decoder input: {yd[0][:12]} ...')    # shifted by one time step of the target as input to decoder is the output of the previous timestep
print(f'Decoder target: {y[0][:12]} ...')
# Out:
# Encoder input: [1971    9   45   24    8  194    7    0    0    0    0    0] ...
# Decoder input: [  4   6   5  38 646   3  45  41 563   7   2   0] ...
# Decoder target: [  6   5  38 646   3  45  41 563   7   2   0   0] ...

# %%
data=tf.data.Dataset.from_tensor_slices((x,yd,y))
data=data.shuffle(buffer_size)

train_data=data.take(int(.9*len(data)))
train_data=train_data.cache()
train_data=train_data.shuffle(buffer_size)
train_data=train_data.batch(batch_size)
train_data=train_data.prefetch(tf.data.AUTOTUNE)
train_data_iterator=train_data.as_numpy_iterator()

val_data=data.skip(int(.9*len(data))).take(int(.1*len(data)))
val_data=val_data.batch(batch_size)
val_data=val_data.prefetch(tf.data.AUTOTUNE)

_=train_data_iterator.next()
print(f'Number of train batches: {len(train_data)}')
print(f'Number of training data: {len(train_data)*batch_size}')
print(f'Number of validation batches: {len(val_data)}')
print(f'Number of validation data: {len(val_data)*batch_size}')
print(f'Encoder Input shape (with batches): {_[0].shape}')
print(f'Decoder Input shape (with batches): {_[1].shape}')
print(f'Target Output shape (with batches): {_[2].shape}')
# Out:
# Number of train batches: 23
# Number of training data: 3427
# Number of validation batches: 3
# Number of validation data: 447
# Encoder Input shape (with batches): (149, 30)
# Decoder Input shape (with batches): (149, 30)
# Target Output shape (with batches): (149, 30)

# %% [markdown]
# # Build Models

# %% [markdown]
# ## Build Encoder

# %%
class Encoder(tf.keras.models.Model):
    def __init__(self,units,embedding_dim,vocab_size,*args,**kwargs) -> None:
        super().__init__(*args,**kwargs)
        self.units=units
        self.vocab_size=vocab_size
        self.embedding_dim=embedding_dim
        self.embedding=Embedding(
            vocab_size,
            embedding_dim,
            name='encoder_embedding',
            mask_zero=True,
            embeddings_initializer=tf.keras.initializers.GlorotNormal()
        )
        self.normalize=LayerNormalization()
        self.lstm=LSTM(
            units,
            dropout=.4,
            return_state=True,
            return_sequences=True,
            name='encoder_lstm',
            kernel_initializer=tf.keras.initializers.GlorotNormal()
        )
    
    def call(self,encoder_inputs):
        self.inputs=encoder_inputs
        x=self.embedding(encoder_inputs)
        x=self.normalize(x)
        x=Dropout(.4)(x)
        encoder_outputs,encoder_state_h,encoder_state_c=self.lstm(x)
        self.outputs=[encoder_state_h,encoder_state_c]
        return encoder_state_h,encoder_state_c

encoder=Encoder(lstm_cells,embedding_dim,vocab_size,name='encoder')
encoder.call(_[0])
# Out:
# (<tf.Tensor: shape=(149, 256), dtype=float32, numpy=
#  array([[-0.04959215, -0.18327035,  0.05506543, ..., -0.08470263,
#           0.2815688 ,  0.01881009],
#         [-0.19857728, -0.0296384 , -0.11076532, ..., -0.01402947,
#           0.24191003, -0.0392483 ],
#         [ 0.06826179, -0.01150786,  0.06888462, ...,  0.06343043,
#           0.2013867 , -0.08283546],
#         ...,
#         [ 0.13488454, -0.16465595,  0.04200165, ...,  0.08211886,
#           0.05292317,  0.08598712],
#         [-0.21165647,  0.12467662, -0.01739328, ...,  0.15997471,
#          -0.03191761,  0.01596804],
#         [-0.09558599, -0.10260496,  0.21115164, ..., -0.05116593,
#          -0.06958725, -0.17244418]], dtype=float32)>,
#  <tf.Tensor: shape=(149, 256), dtype=float32, numpy=
#  array([[-0.10121451, -0.39466888,  0.12731197, ..., -0.14617151,
#           0.440769  ,  0.0585845 ],
#         [-0.42408904, -0.06222718, -0.24575071, ..., -0.0249832 ,
#           0.37073824, -0.11796436],
#         [ 0.14442863, -0.02207989,  0.12460309, ...,  0.10521004,
#           0.4223418 , -0.19623514],
#         ...,
#         [ 0.2786747 , -0.36168814,  0.0994769 , ...,  0.14538282,
#           0.08115964,  0.24995226],
#         [-0.46584162,  0.26461753, -0.03894094, ...,  0.30090335,
#          -0.04726121,  0.05219355],
#         [-0.19579674, -0.21574591,  0.4831341 , ..., -0.08590014,
#          -0.10615902, -0.5990574 ]], dtype=float32)>)

# %% [markdown]
# ##  Build Decoder

# %%
class Decoder(tf.keras.models.Model):
    def __init__(self,units,embedding_dim,vocab_size,*args,**kwargs) -> None:
        super().__init__(*args,**kwargs)
        self.units=units
        self.embedding_dim=embedding_dim
        self.vocab_size=vocab_size
        self.embedding=Embedding(
            vocab_size,
            embedding_dim,
            name='decoder_embedding',
            mask_zero=True,
            embeddings_initializer=tf.keras.initializers.HeNormal()
        )
        self.normalize=LayerNormalization()
        self.lstm=LSTM(
            units,
            dropout=.4,
            return_state=True,
            return_sequences=True,
            name='decoder_lstm',
            kernel_initializer=tf.keras.initializers.HeNormal()
        )
        self.fc=Dense(
            vocab_size,
            activation='softmax',
            name='decoder_dense',
            kernel_initializer=tf.keras.initializers.HeNormal()
        )
    
    def call(self,decoder_inputs,encoder_states):
        x=self.embedding(decoder_inputs)
        x=self.normalize(x)
        x=Dropout(.4)(x)
        x,decoder_state_h,decoder_state_c=self.lstm(x,initial_state=encoder_states)
        x=self.normalize(x)
        x=Dropout(.4)(x)
        return self.fc(x)

decoder=Decoder(lstm_cells,embedding_dim,vocab_size,name='decoder')
decoder(_[1][:1],encoder(_[0][:1]))
# Out:
# <tf.Tensor: shape=(1, 30, 2443), dtype=float32, numpy=
# array([[[5.8486237e-04, 3.0501698e-05, 2.8061643e-04, ...,
#          1.1261761e-04, 1.1655961e-04, 3.6062128e-04],
#         [2.0104893e-03, 7.5650214e-06, 1.2102424e-04, ...,
#          2.2509443e-05, 2.1440155e-04, 1.9390849e-04],
#         [1.3928626e-03, 1.4102612e-05, 6.5376674e-04, ...,
#          3.6792830e-05, 1.8812731e-04, 2.8729779e-04],
#         ...,
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04]]], dtype=float32)>

# %% [markdown]
# ## Build Training Model

# %%
class ChatBotTrainer(tf.keras.models.Model):
    def __init__(self,encoder,decoder,*args,**kwargs):
        super().__init__(*args,**kwargs)
        self.encoder=encoder
        self.decoder=decoder

    def loss_fn(self,y_true,y_pred):
        loss=self.loss(y_true,y_pred)
        mask=tf.math.logical_not(tf.math.equal(y_true,0))
        mask=tf.cast(mask,dtype=loss.dtype)
        loss*=mask
        return tf.reduce_mean(loss)
    
    def accuracy_fn(self,y_true,y_pred):
        pred_values = tf.cast(tf.argmax(y_pred, axis=-1), dtype='int64')
        correct = tf.cast(tf.equal(y_true, pred_values), dtype='float64')
        mask = tf.cast(tf.greater(y_true, 0), dtype='float64')
        n_correct = tf.keras.backend.sum(mask * correct)
        n_total = tf.keras.backend.sum(mask)
        return n_correct / n_total

    def call(self,inputs):
        encoder_inputs,decoder_inputs=inputs
        encoder_states=self.encoder(encoder_inputs)
        return self.decoder(decoder_inputs,encoder_states)

    def train_step(self,batch):
        encoder_inputs,decoder_inputs,y=batch
        with tf.GradientTape() as tape:
            encoder_states=self.encoder(encoder_inputs,training=True)
            y_pred=self.decoder(decoder_inputs,encoder_states,training=True)
            loss=self.loss_fn(y,y_pred)
            acc=self.accuracy_fn(y,y_pred)

        variables=self.encoder.trainable_variables+self.decoder.trainable_variables
        grads=tape.gradient(loss,variables)
        self.optimizer.apply_gradients(zip(grads,variables))
        metrics={'loss':loss,'accuracy':acc}
        return metrics
    
    def test_step(self,batch):
        encoder_inputs,decoder_inputs,y=batch
        encoder_states=self.encoder(encoder_inputs,training=True)
        y_pred=self.decoder(decoder_inputs,encoder_states,training=True)
        loss=self.loss_fn(y,y_pred)
        acc=self.accuracy_fn(y,y_pred)
        metrics={'loss':loss,'accuracy':acc}
        return metrics

# %%
model=ChatBotTrainer(encoder,decoder,name='chatbot_trainer')
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    weighted_metrics=['loss','accuracy']
)
model(_[:2])
# Out:
# <tf.Tensor: shape=(149, 30, 2443), dtype=float32, numpy=
# array([[[5.8486313e-04, 3.0501671e-05, 2.8061631e-04, ...,
#          1.1261773e-04, 1.1655968e-04, 3.6062117e-04],
#         [2.0104868e-03, 7.5650200e-06, 1.2102428e-04, ...,
#          2.2509426e-05, 2.1440152e-04, 1.9390855e-04],
#         [1.3928637e-03, 1.4102613e-05, 6.5376703e-04, ...,
#          3.6792830e-05, 1.8812731e-04, 2.8729765e-04],
#         ...,
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04]],
#
#        [[8.6955057e-04, 2.5108673e-05, 2.1167369e-04, ...,
#          1.2025899e-04, 5.0743653e-05, 2.7794269e-04],
#         [8.1651594e-04, 7.2374423e-06, 1.6007514e-04, ...,
#          1.8683783e-04, 8.7828821e-06, 9.3338553e-05],
#         [3.2901153e-04, 3.1168769e-05, 2.1265828e-04, ...,
#          6.1048422e-04, 2.0440139e-05, 2.5373799e-04],
#         ...,
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04]],
#
#        [[1.1895834e-03, 1.7452768e-04, 5.4876792e-04, ...,
#          1.4421044e-04, 4.4435285e-05, 1.4626046e-04],
#         [1.4915796e-03, 4.9862807e-04, 5.2944426e-05, ...,
#          3.1478292e-05, 3.6860208e-06, 1.1160753e-04],
#         [3.8512045e-04, 5.4218771e-04, 9.3272130e-05, ...,
#          1.3597657e-04, 2.7457847e-05, 1.0124213e-04],
#         ...,
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04]],
#
#        ...,
#
#        [[5.5611850e-04, 2.5493369e-05, 5.3857703e-04, ...,
#          7.3062998e-05, 2.2289523e-05, 1.5644428e-04],
#         [2.0381651e-04, 3.0111356e-05, 3.0388543e-04, ...,
#          2.2909521e-04, 1.4968960e-04, 1.3612889e-04],
#         [2.8934111e-04, 1.4957296e-05, 1.2478864e-04, ...,
#          5.3632964e-04, 1.1461672e-04, 3.0366008e-04],
#         ...,
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04]],
#
#        [[2.7431472e-04, 1.1887681e-04, 5.5996713e-04, ...,
#          1.4840389e-04, 1.0823071e-04, 3.0609677e-04],
#         [8.0795857e-05, 7.9068486e-05, 1.5844146e-04, ...,
#          9.7457334e-05, 1.0030574e-04, 3.2479072e-04],
#         [6.4922799e-04, 8.3513427e-05, 1.6902899e-04, ...,
#          1.9695894e-04, 8.1859826e-06, 1.6740320e-04],
#         ...,
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04]],
#
#        [[3.8420988e-04, 4.7521618e-05, 4.5523533e-04, ...,
#          2.7654000e-04, 1.6949893e-04, 3.7935449e-04],
#         [1.7367654e-04, 3.8151786e-04, 8.6291824e-05, ...,
#          2.7229922e-04, 2.6104986e-04, 2.0337764e-03],
#         [2.1237208e-04, 4.1286557e-04, 1.4742478e-04, ...,
#          4.6233847e-04, 3.3824437e-04, 6.8125193e-04],
#         ...,
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04],
#         [4.0933277e-04, 4.0933277e-04, 4.0933277e-04, ...,
#          4.0933277e-04, 4.0933277e-04, 4.0933277e-04]]], dtype=float32)>

# %% [markdown]
# ##  Train Model

# %%
history=model.fit(
    train_data,
    epochs=100,
    validation_data=val_data,
    callbacks=[
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint('ckpt',verbose=1,save_best_only=True)
    ]
)
# Out:
# Epoch 1/100
# 23/23 [==============================] - ETA: 0s - loss: 1.6758 - accuracy: 0.2185
# Epoch 1: val_loss improved from inf to 1.29262, saving model to ckpt
# 23/23 [==============================] - 42s 1s/step - loss: 1.6662 - accuracy: 0.2210 - val_loss: 1.2926 - val_accuracy: 0.3051
# Epoch 2/100
# 23/23 [==============================] - ETA: 0s - loss: 1.2392 - accuracy: 0.3097
# Epoch 2: val_loss improved from 1.29262 to 1.02188, saving model to ckpt
# 23/23 [==============================] - 30s 1s/step - loss: 1.2438 - accuracy: 0.3099 - val_loss: 1.0219 - val_accuracy: 0.3421
# Epoch 3/100
# 23/23 [==============================] - ETA: 0s - loss: 1.1056 - accuracy: 0.3381
# Epoch 3: val_loss did not improve from 1.02188
# 23/23 [==============================] - 3s 131ms/step - loss: 1.1072 - accuracy: 0.3380 - val_loss: 1.1032 - val_accuracy: 0.3187
# Epoch 4/100
# 23/23 [==============================] - ETA: 0s - loss: 1.0213 - accuracy: 0.3581
# Epoch 4: val_loss improved from 1.02188 to 0.98628, saving model to ckpt
# 23/23 [==============================] - 28s 1s/step - loss: 1.0215 - accuracy: 0.3584 - val_loss: 0.9863 - val_accuracy: 0.3850
# Epoch 5/100
# 23/23 [==============================] - ETA: 0s - loss: 0.9660 - accuracy: 0.3688
# Epoch 5: val_loss improved from 0.98628 to 0.92717, saving model to ckpt
# 23/23 [==============================] - 26s 1s/step - loss: 0.9682 - accuracy: 0.3683 - val_loss: 0.9272 - val_accuracy: 0.3872
# Epoch 6/100
# 23/23 [==============================] - ETA: 0s - loss: 0.9160 - accuracy: 0.3815
# Epoch 6: val_loss improved from 0.92717 to 0.86549, saving model to ckpt
# 23/23 [==============================] - 26s 1s/step - loss: 0.9179 - accuracy: 0.3801 - val_loss: 0.8655 - val_accuracy: 0.4168
# Epoch 7/100
# 23/23 [==============================] - ETA: 0s - loss: 0.8801 - accuracy: 0.3898
# Epoch 7: val_loss did not improve from 0.86549
# 23/23 [==============================] - 2s 71ms/step - loss: 0.8809 - accuracy: 0.3895 - val_loss: 0.8997 - val_accuracy: 0.4155
# Epoch 8/100
# 23/23 [==============================] - ETA: 0s - loss: 0.8487 - accuracy: 0.4030
# Epoch 8: val_loss did not improve from 0.86549
# 23/23 [==============================] - 2s 72ms/step - loss: 0.8511 - accuracy: 0.4028 - val_loss: 0.8683 - val_accuracy: 0.4086
# Epoch 9/100
# 23/23 [==============================] - ETA: 0s - loss: 0.8202 - accuracy: 0.4128
# Epoch 9: val_loss improved from 0.86549 to 0.82070, saving model to ckpt
# 23/23 [==============================] - 26s 1s/step - loss: 0.8226 - accuracy: 0.4119 - val_loss: 0.8207 - val_accuracy: 0.4357
# Epoch 10/100
# 23/23 [==============================] - ETA: 0s - loss: 0.7914 - accuracy: 0.4238
# Epoch 10: val_loss did not improve from 0.82070
# 23/23 [==============================] - 2s 73ms/step - loss: 0.7924 - accuracy: 0.4236 - val_loss: 0.9095 - val_accuracy: 0.4064
# Epoch 11/100
# 23/23 [==============================] - ETA: 0s - loss: 0.7697 - accuracy: 0.4279
# Epoch 11: val_loss did not improve from 0.82070
# 23/23 [==============================] - 1s 49ms/step - loss: 0.7718 - accuracy: 0.4272 - val_loss: 0.8310 - val_accuracy: 0.4239
# Epoch 12/100
# 23/23 [==============================] - ETA: 0s - loss: 0.7496 - accuracy: 0.4366
# Epoch 12: val_loss improved from 0.82070 to 0.75876, saving model to ckpt
# 23/23 [==============================] - 26s 1s/step - loss: 0.7523 - accuracy: 0.4355 - val_loss: 0.7588 - val_accuracy: 0.4288
# Epoch 13/100
# 23/23 [==============================] - ETA: 0s - loss: 0.7314 - accuracy: 0.4423
# Epoch 13: val_loss improved from 0.75876 to 0.64336, saving model to ckpt
# 23/23 [==============================] - 26s 1s/step - loss: 0.7329 - accuracy: 0.4420 - val_loss: 0.6434 - val_accuracy: 0.5008
# Epoch 14/100
# 23/23 [==============================] - ETA: 0s - loss: 0.7116 - accuracy: 0.4514
# Epoch 14: val_loss did not improve from 0.64336
# 23/23 [==============================] - 1s 46ms/step - loss: 0.7122 - accuracy: 0.4498 - val_loss: 0.6825 - val_accuracy: 0.4880
# Epoch 15/100
# 23/23 [==============================] - ETA: 0s - loss: 0.6946 - accuracy: 0.4615
# Epoch 15: val_loss did not improve from 0.64336
# 23/23 [==============================] - 1s 59ms/step - loss: 0.6947 - accuracy: 0.4615 - val_loss: 0.7571 - val_accuracy: 0.4415
# Epoch 16/100
# 23/23 [==============================] - ETA: 0s - loss: 0.6766 - accuracy: 0.4682
# Epoch 16: val_loss did not improve from 0.64336
# 23/23 [==============================] - 1s 47ms/step - loss: 0.6755 - accuracy: 0.4693 - val_loss: 0.6841 - val_accuracy: 0.4641
# Epoch 17/100
# 23/23 [==============================] - ETA: 0s - loss: 0.6633 - accuracy: 0.4737
# Epoch 17: val_loss did not improve from 0.64336
# 23/23 [==============================] - 1s 50ms/step - loss: 0.6617 - accuracy: 0.4733 - val_loss: 0.6984 - val_accuracy: 0.4973
# Epoch 18/100
# 23/23 [==============================] - ETA: 0s - loss: 0.6527 - accuracy: 0.4779
# Epoch 18: val_loss did not improve from 0.64336
# 23/23 [==============================] - 1s 42ms/step - loss: 0.6540 - accuracy: 0.4777 - val_loss: 0.7439 - val_accuracy: 0.4544
# Epoch 19/100
# 23/23 [==============================] - ETA: 0s - loss: 0.6420 - accuracy: 0.4834
# Epoch 19: val_loss did not improve from 0.64336
# 23/23 [==============================] - 1s 52ms/step - loss: 0.6444 - accuracy: 0.4825 - val_loss: 0.6459 - val_accuracy: 0.4873
# Epoch 20/100
# 23/23 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.4897
# Epoch 20: val_loss improved from 0.64336 to 0.62305, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.6311 - accuracy: 0.4890 - val_loss: 0.6230 - val_accuracy: 0.5195
# Epoch 21/100
# 23/23 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.4960
# Epoch 21: val_loss did not improve from 0.62305
# 23/23 [==============================] - 1s 36ms/step - loss: 0.6184 - accuracy: 0.4955 - val_loss: 0.6339 - val_accuracy: 0.5286
# Epoch 22/100
# 23/23 [==============================] - ETA: 0s - loss: 0.6055 - accuracy: 0.5056
# Epoch 22: val_loss improved from 0.62305 to 0.58246, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.6053 - accuracy: 0.5055 - val_loss: 0.5825 - val_accuracy: 0.5036
# Epoch 23/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5982 - accuracy: 0.5059
# Epoch 23: val_loss did not improve from 0.58246
# 23/23 [==============================] - 1s 50ms/step - loss: 0.5974 - accuracy: 0.5064 - val_loss: 0.7032 - val_accuracy: 0.4860
# Epoch 24/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5928 - accuracy: 0.5111
# Epoch 24: val_loss did not improve from 0.58246
# 23/23 [==============================] - 1s 52ms/step - loss: 0.5952 - accuracy: 0.5108 - val_loss: 0.7244 - val_accuracy: 0.5173
# Epoch 25/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5792 - accuracy: 0.5191
# Epoch 25: val_loss improved from 0.58246 to 0.57235, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.5801 - accuracy: 0.5188 - val_loss: 0.5723 - val_accuracy: 0.5542
# Epoch 26/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5736 - accuracy: 0.5245
# Epoch 26: val_loss improved from 0.57235 to 0.54582, saving model to ckpt
# 23/23 [==============================] - 26s 1s/step - loss: 0.5785 - accuracy: 0.5223 - val_loss: 0.5458 - val_accuracy: 0.5432
# Epoch 27/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5633 - accuracy: 0.5247
# Epoch 27: val_loss did not improve from 0.54582
# 23/23 [==============================] - 1s 32ms/step - loss: 0.5620 - accuracy: 0.5251 - val_loss: 0.6362 - val_accuracy: 0.5535
# Epoch 28/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5577 - accuracy: 0.5297
# Epoch 28: val_loss did not improve from 0.54582
# 23/23 [==============================] - 1s 50ms/step - loss: 0.5588 - accuracy: 0.5289 - val_loss: 0.5725 - val_accuracy: 0.5399
# Epoch 29/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5461 - accuracy: 0.5398
# Epoch 29: val_loss did not improve from 0.54582
# 23/23 [==============================] - 1s 43ms/step - loss: 0.5470 - accuracy: 0.5379 - val_loss: 0.6165 - val_accuracy: 0.5683
# Epoch 30/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5486 - accuracy: 0.5363
# Epoch 30: val_loss improved from 0.54582 to 0.54275, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.5526 - accuracy: 0.5361 - val_loss: 0.5427 - val_accuracy: 0.5156
# Epoch 31/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.5406
# Epoch 31: val_loss did not improve from 0.54275
# 23/23 [==============================] - 1s 52ms/step - loss: 0.5369 - accuracy: 0.5401 - val_loss: 0.5728 - val_accuracy: 0.5154
# Epoch 32/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5309 - accuracy: 0.5475
# Epoch 32: val_loss did not improve from 0.54275
# 23/23 [==============================] - 1s 38ms/step - loss: 0.5322 - accuracy: 0.5472 - val_loss: 0.6393 - val_accuracy: 0.5226
# Epoch 33/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5249 - accuracy: 0.5515
# Epoch 33: val_loss did not improve from 0.54275
# 23/23 [==============================] - 1s 38ms/step - loss: 0.5247 - accuracy: 0.5509 - val_loss: 0.6293 - val_accuracy: 0.5315
# Epoch 34/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5173 - accuracy: 0.5529
# Epoch 34: val_loss did not improve from 0.54275
# 23/23 [==============================] - 1s 48ms/step - loss: 0.5172 - accuracy: 0.5525 - val_loss: 0.6170 - val_accuracy: 0.5615
# Epoch 35/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.5115 - accuracy: 0.5610
# Epoch 35: val_loss improved from 0.54275 to 0.54099, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.5142 - accuracy: 0.5582 - val_loss: 0.5410 - val_accuracy: 0.5641
# Epoch 36/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5079 - accuracy: 0.5621
# Epoch 36: val_loss did not improve from 0.54099
# 23/23 [==============================] - 1s 31ms/step - loss: 0.5071 - accuracy: 0.5630 - val_loss: 0.5847 - val_accuracy: 0.5382
# Epoch 37/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5023 - accuracy: 0.5657
# Epoch 37: val_loss improved from 0.54099 to 0.47895, saving model to ckpt
# 23/23 [==============================] - 26s 1s/step - loss: 0.5019 - accuracy: 0.5658 - val_loss: 0.4790 - val_accuracy: 0.5748
# Epoch 38/100
# 23/23 [==============================] - ETA: 0s - loss: 0.5008 - accuracy: 0.5671
# Epoch 38: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 40ms/step - loss: 0.5020 - accuracy: 0.5670 - val_loss: 0.4879 - val_accuracy: 0.5592
# Epoch 39/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4937 - accuracy: 0.5698
# Epoch 39: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 39ms/step - loss: 0.4938 - accuracy: 0.5696 - val_loss: 0.5472 - val_accuracy: 0.5704
# Epoch 40/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.5751
# Epoch 40: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 35ms/step - loss: 0.4851 - accuracy: 0.5756 - val_loss: 0.5015 - val_accuracy: 0.5846
# Epoch 41/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4841 - accuracy: 0.5771
# Epoch 41: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 45ms/step - loss: 0.4868 - accuracy: 0.5763 - val_loss: 0.5453 - val_accuracy: 0.5630
# Epoch 42/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4790 - accuracy: 0.5800
# Epoch 42: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 50ms/step - loss: 0.4809 - accuracy: 0.5788 - val_loss: 0.5532 - val_accuracy: 0.5497
# Epoch 43/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4765 - accuracy: 0.5810
# Epoch 43: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 50ms/step - loss: 0.4781 - accuracy: 0.5796 - val_loss: 0.6151 - val_accuracy: 0.5387
# Epoch 44/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4706 - accuracy: 0.5852
# Epoch 44: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 38ms/step - loss: 0.4709 - accuracy: 0.5849 - val_loss: 0.4868 - val_accuracy: 0.6035
# Epoch 45/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.5876
# Epoch 45: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 36ms/step - loss: 0.4675 - accuracy: 0.5872 - val_loss: 0.5100 - val_accuracy: 0.5852
# Epoch 46/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.5884
# Epoch 46: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 31ms/step - loss: 0.4641 - accuracy: 0.5883 - val_loss: 0.5619 - val_accuracy: 0.5706
# Epoch 47/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4564 - accuracy: 0.5944
# Epoch 47: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 31ms/step - loss: 0.4571 - accuracy: 0.5939 - val_loss: 0.5009 - val_accuracy: 0.5826
# Epoch 48/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.4503 - accuracy: 0.6005
# Epoch 48: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 38ms/step - loss: 0.4516 - accuracy: 0.5975 - val_loss: 0.4929 - val_accuracy: 0.5992
# Epoch 49/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.5984
# Epoch 49: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 52ms/step - loss: 0.4527 - accuracy: 0.5977 - val_loss: 0.5340 - val_accuracy: 0.5527
# Epoch 50/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4466 - accuracy: 0.6024
# Epoch 50: val_loss did not improve from 0.47895
# 23/23 [==============================] - 1s 43ms/step - loss: 0.4500 - accuracy: 0.6010 - val_loss: 0.5130 - val_accuracy: 0.5919
# Epoch 51/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.4448 - accuracy: 0.6033
# Epoch 51: val_loss improved from 0.47895 to 0.47533, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.4424 - accuracy: 0.6023 - val_loss: 0.4753 - val_accuracy: 0.6050
# Epoch 52/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4358 - accuracy: 0.6081
# Epoch 52: val_loss did not improve from 0.47533
# 23/23 [==============================] - 1s 36ms/step - loss: 0.4349 - accuracy: 0.6080 - val_loss: 0.5039 - val_accuracy: 0.6102
# Epoch 53/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4401 - accuracy: 0.6045
# Epoch 53: val_loss improved from 0.47533 to 0.46343, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.4400 - accuracy: 0.6054 - val_loss: 0.4634 - val_accuracy: 0.6111
# Epoch 54/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4328 - accuracy: 0.6113
# Epoch 54: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 31ms/step - loss: 0.4345 - accuracy: 0.6107 - val_loss: 0.5284 - val_accuracy: 0.5774
# Epoch 55/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4322 - accuracy: 0.6158
# Epoch 55: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 45ms/step - loss: 0.4330 - accuracy: 0.6151 - val_loss: 0.5356 - val_accuracy: 0.5961
# Epoch 56/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4287 - accuracy: 0.6161
# Epoch 56: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 44ms/step - loss: 0.4264 - accuracy: 0.6161 - val_loss: 0.4739 - val_accuracy: 0.6150
# Epoch 57/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4271 - accuracy: 0.6159
# Epoch 57: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 35ms/step - loss: 0.4277 - accuracy: 0.6154 - val_loss: 0.5750 - val_accuracy: 0.5981
# Epoch 58/100
# 21/23 [==========================>...] - ETA: 0s - loss: 0.4231 - accuracy: 0.6179
# Epoch 58: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 31ms/step - loss: 0.4224 - accuracy: 0.6152 - val_loss: 0.5218 - val_accuracy: 0.5946
# Epoch 59/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4239 - accuracy: 0.6175
# Epoch 59: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 38ms/step - loss: 0.4262 - accuracy: 0.6170 - val_loss: 0.5820 - val_accuracy: 0.6052
# Epoch 60/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.6197
# Epoch 60: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 31ms/step - loss: 0.4203 - accuracy: 0.6199 - val_loss: 0.5021 - val_accuracy: 0.5962
# Epoch 61/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.6228
# Epoch 61: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 38ms/step - loss: 0.4128 - accuracy: 0.6229 - val_loss: 0.4644 - val_accuracy: 0.6196
# Epoch 62/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.6229
# Epoch 62: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 30ms/step - loss: 0.4141 - accuracy: 0.6221 - val_loss: 0.4981 - val_accuracy: 0.5896
# Epoch 63/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4118 - accuracy: 0.6274
# Epoch 63: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 41ms/step - loss: 0.4147 - accuracy: 0.6259 - val_loss: 0.5889 - val_accuracy: 0.5980
# Epoch 64/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.4101 - accuracy: 0.6270
# Epoch 64: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 54ms/step - loss: 0.4086 - accuracy: 0.6273 - val_loss: 0.5480 - val_accuracy: 0.5623
# Epoch 65/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.6266
# Epoch 65: val_loss did not improve from 0.46343
# 23/23 [==============================] - 1s 37ms/step - loss: 0.4096 - accuracy: 0.6259 - val_loss: 0.4820 - val_accuracy: 0.5972
# Epoch 66/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4058 - accuracy: 0.6284
# Epoch 66: val_loss improved from 0.46343 to 0.41219, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.4062 - accuracy: 0.6273 - val_loss: 0.4122 - val_accuracy: 0.6515
# Epoch 67/100
# 23/23 [==============================] - ETA: 0s - loss: 0.4026 - accuracy: 0.6323
# Epoch 67: val_loss did not improve from 0.41219
# 23/23 [==============================] - 1s 42ms/step - loss: 0.4046 - accuracy: 0.6315 - val_loss: 0.4347 - val_accuracy: 0.6520
# Epoch 68/100
# 21/23 [==========================>...] - ETA: 0s - loss: 0.3996 - accuracy: 0.6344
# Epoch 68: val_loss did not improve from 0.41219
# 23/23 [==============================] - 1s 31ms/step - loss: 0.4026 - accuracy: 0.6316 - val_loss: 0.4258 - val_accuracy: 0.6492
# Epoch 69/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3961 - accuracy: 0.6366
# Epoch 69: val_loss did not improve from 0.41219
# 23/23 [==============================] - 1s 34ms/step - loss: 0.3977 - accuracy: 0.6358 - val_loss: 0.4849 - val_accuracy: 0.6441
# Epoch 70/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3943 - accuracy: 0.6401
# Epoch 70: val_loss improved from 0.41219 to 0.39685, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.3931 - accuracy: 0.6400 - val_loss: 0.3969 - val_accuracy: 0.6441
# Epoch 71/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3943 - accuracy: 0.6392
# Epoch 71: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 39ms/step - loss: 0.3976 - accuracy: 0.6378 - val_loss: 0.5026 - val_accuracy: 0.6021
# Epoch 72/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.6400
# Epoch 72: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 35ms/step - loss: 0.3941 - accuracy: 0.6398 - val_loss: 0.5002 - val_accuracy: 0.6153
# Epoch 73/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3919 - accuracy: 0.6387
# Epoch 73: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 35ms/step - loss: 0.3940 - accuracy: 0.6370 - val_loss: 0.4461 - val_accuracy: 0.6204
# Epoch 74/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.6456
# Epoch 74: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 40ms/step - loss: 0.3898 - accuracy: 0.6447 - val_loss: 0.4588 - val_accuracy: 0.6431
# Epoch 75/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3879 - accuracy: 0.6403
# Epoch 75: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 31ms/step - loss: 0.3897 - accuracy: 0.6388 - val_loss: 0.4493 - val_accuracy: 0.5981
# Epoch 76/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3832 - accuracy: 0.6485
# Epoch 76: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 46ms/step - loss: 0.3851 - accuracy: 0.6473 - val_loss: 0.4853 - val_accuracy: 0.6300
# Epoch 77/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.3789 - accuracy: 0.6489
# Epoch 77: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 38ms/step - loss: 0.3819 - accuracy: 0.6464 - val_loss: 0.5206 - val_accuracy: 0.6175
# Epoch 78/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3818 - accuracy: 0.6451
# Epoch 78: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 39ms/step - loss: 0.3840 - accuracy: 0.6440 - val_loss: 0.4547 - val_accuracy: 0.6185
# Epoch 79/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3809 - accuracy: 0.6513
# Epoch 79: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 39ms/step - loss: 0.3814 - accuracy: 0.6523 - val_loss: 0.4754 - val_accuracy: 0.6403
# Epoch 80/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3790 - accuracy: 0.6461
# Epoch 80: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 46ms/step - loss: 0.3809 - accuracy: 0.6455 - val_loss: 0.5389 - val_accuracy: 0.5995
# Epoch 81/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.6550
# Epoch 81: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 31ms/step - loss: 0.3691 - accuracy: 0.6556 - val_loss: 0.4143 - val_accuracy: 0.6612
# Epoch 82/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.6544
# Epoch 82: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 42ms/step - loss: 0.3699 - accuracy: 0.6546 - val_loss: 0.5190 - val_accuracy: 0.6112
# Epoch 83/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3695 - accuracy: 0.6537
# Epoch 83: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 30ms/step - loss: 0.3699 - accuracy: 0.6536 - val_loss: 0.4923 - val_accuracy: 0.6315
# Epoch 84/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.6563
# Epoch 84: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 35ms/step - loss: 0.3721 - accuracy: 0.6552 - val_loss: 0.4265 - val_accuracy: 0.6361
# Epoch 85/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.6579
# Epoch 85: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 38ms/step - loss: 0.3649 - accuracy: 0.6592 - val_loss: 0.4169 - val_accuracy: 0.6366
# Epoch 86/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.6586
# Epoch 86: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 32ms/step - loss: 0.3635 - accuracy: 0.6596 - val_loss: 0.5629 - val_accuracy: 0.6110
# Epoch 87/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.6613
# Epoch 87: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 31ms/step - loss: 0.3628 - accuracy: 0.6615 - val_loss: 0.4366 - val_accuracy: 0.6501
# Epoch 88/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3624 - accuracy: 0.6630
# Epoch 88: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 47ms/step - loss: 0.3647 - accuracy: 0.6617 - val_loss: 0.4275 - val_accuracy: 0.6499
# Epoch 89/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.6615
# Epoch 89: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 35ms/step - loss: 0.3626 - accuracy: 0.6606 - val_loss: 0.5007 - val_accuracy: 0.6592
# Epoch 90/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3606 - accuracy: 0.6646
# Epoch 90: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 35ms/step - loss: 0.3592 - accuracy: 0.6655 - val_loss: 0.4136 - val_accuracy: 0.6374
# Epoch 91/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3591 - accuracy: 0.6633
# Epoch 91: val_loss did not improve from 0.39685
# 23/23 [==============================] - 1s 31ms/step - loss: 0.3611 - accuracy: 0.6616 - val_loss: 0.4397 - val_accuracy: 0.6610
# Epoch 92/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3582 - accuracy: 0.6623
# Epoch 92: val_loss improved from 0.39685 to 0.38757, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.3590 - accuracy: 0.6603 - val_loss: 0.3876 - val_accuracy: 0.6343
# Epoch 93/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.6635
# Epoch 93: val_loss did not improve from 0.38757
# 23/23 [==============================] - 1s 32ms/step - loss: 0.3612 - accuracy: 0.6624 - val_loss: 0.4863 - val_accuracy: 0.6287
# Epoch 94/100
# 21/23 [==========================>...] - ETA: 0s - loss: 0.3578 - accuracy: 0.6655
# Epoch 94: val_loss did not improve from 0.38757
# 23/23 [==============================] - 1s 31ms/step - loss: 0.3575 - accuracy: 0.6645 - val_loss: 0.3987 - val_accuracy: 0.6702
# Epoch 95/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.6678
# Epoch 95: val_loss did not improve from 0.38757
# 23/23 [==============================] - 1s 31ms/step - loss: 0.3522 - accuracy: 0.6674 - val_loss: 0.4565 - val_accuracy: 0.6306
# Epoch 96/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3503 - accuracy: 0.6693
# Epoch 96: val_loss improved from 0.38757 to 0.37553, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.3505 - accuracy: 0.6688 - val_loss: 0.3755 - val_accuracy: 0.6687
# Epoch 97/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3495 - accuracy: 0.6682
# Epoch 97: val_loss did not improve from 0.37553
# 23/23 [==============================] - 1s 39ms/step - loss: 0.3497 - accuracy: 0.6672 - val_loss: 0.4937 - val_accuracy: 0.6020
# Epoch 98/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3454 - accuracy: 0.6744
# Epoch 98: val_loss did not improve from 0.37553
# 23/23 [==============================] - 1s 35ms/step - loss: 0.3451 - accuracy: 0.6755 - val_loss: 0.4155 - val_accuracy: 0.6729
# Epoch 99/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.6709
# Epoch 99: val_loss improved from 0.37553 to 0.36597, saving model to ckpt
# 23/23 [==============================] - 25s 1s/step - loss: 0.3502 - accuracy: 0.6701 - val_loss: 0.3660 - val_accuracy: 0.6937
# Epoch 100/100
# 23/23 [==============================] - ETA: 0s - loss: 0.3467 - accuracy: 0.6736
# Epoch 100: val_loss did not improve from 0.36597
# 23/23 [==============================] - 1s 35ms/step - loss: 0.3473 - accuracy: 0.6728 - val_loss: 0.4002 - val_accuracy: 0.6380

# %% [markdown]
# #  Visualize Metrics

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
ax[0].plot(history.history['loss'],label='loss',c='red')
ax[0].plot(history.history['val_loss'],label='val_loss',c = 'blue')
ax[0].set_xlabel('Epochs')
ax[1].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[1].set_ylabel('Accuracy')
ax[0].set_title('Loss Metrics')
ax[1].set_title('Accuracy Metrics')
ax[1].plot(history.history['accuracy'],label='accuracy')
ax[1].plot(history.history['val_accuracy'],label='val_accuracy')
ax[0].legend()
ax[1].legend()
plt.show()

# %% [markdown]
# # Save Model

# %%
model.load_weights('ckpt')
model.save('models',save_format='tf')

# %%
for idx,i in enumerate(model.layers):
    print('Encoder layers:' if idx==0 else 'Decoder layers: ')
    for j in i.layers:
        print(j)
    print('---------------------')
# Out:
# Encoder layers:
# <keras.layers.core.embedding.Embedding object at 0x790263b27bd0>
# <keras.layers.normalization.layer_normalization.LayerNormalization object at 0x790263b27b90>
# <keras.layers.rnn.lstm.LSTM object at 0x79025920b210>
# ---------------------
# Decoder layers:
# <keras.layers.core.embedding.Embedding object at 0x790263b75b10>
# <keras.layers.normalization.layer_normalization.LayerNormalization object at 0x790263b75810>
# <keras.layers.rnn.lstm.LSTM object at 0x790263b56210>
# <keras.layers.core.dense.Dense object at 0x790263b56a10>
# ---------------------

# %% [markdown]
# # Create Inference Model

# %%
class ChatBot(tf.keras.models.Model):
    def __init__(self,base_encoder,base_decoder,*args,**kwargs):
        super().__init__(*args,**kwargs)
        self.encoder,self.decoder=self.build_inference_model(base_encoder,base_decoder)

    def build_inference_model(self,base_encoder,base_decoder):
        encoder_inputs=tf.keras.Input(shape=(None,))
        x=base_encoder.layers[0](encoder_inputs)
        x=base_encoder.layers[1](x)
        x,encoder_state_h,encoder_state_c=base_encoder.layers[2](x)
        encoder=tf.keras.models.Model(inputs=encoder_inputs,outputs=[encoder_state_h,encoder_state_c],name='chatbot_encoder')

        decoder_input_state_h=tf.keras.Input(shape=(lstm_cells,))
        decoder_input_state_c=tf.keras.Input(shape=(lstm_cells,))
        decoder_inputs=tf.keras.Input(shape=(None,))
        x=base_decoder.layers[0](decoder_inputs)
        x=base_encoder.layers[1](x)
        x,decoder_state_h,decoder_state_c=base_decoder.layers[2](x,initial_state=[decoder_input_state_h,decoder_input_state_c])
        decoder_outputs=base_decoder.layers[-1](x)
        decoder=tf.keras.models.Model(
            inputs=[decoder_inputs,[decoder_input_state_h,decoder_input_state_c]],
            outputs=[decoder_outputs,[decoder_state_h,decoder_state_c]],name='chatbot_decoder'
        )
        return encoder,decoder

    def summary(self):
        self.encoder.summary()
        self.decoder.summary()

    def softmax(self,z):
        return np.exp(z)/sum(np.exp(z))

    def sample(self,conditional_probability,temperature=0.5):
        conditional_probability = np.asarray(conditional_probability).astype("float64")
        conditional_probability = np.log(conditional_probability) / temperature
        reweighted_conditional_probability = self.softmax(conditional_probability)
        probas = np.random.multinomial(1, reweighted_conditional_probability, 1)
        return np.argmax(probas)

    def preprocess(self,text):
        text=clean_text(text)
        seq=np.zeros((1,max_sequence_length),dtype=np.int32)
        for i,word in enumerate(text.split()):
            seq[:,i]=sequences2ids(word).numpy()[0]
        return seq
    
    def postprocess(self,text):
        text=re.sub(' - ','-',text.lower())
        text=re.sub(' [.] ','. ',text)
        text=re.sub(' [1] ','1',text)
        text=re.sub(' [2] ','2',text)
        text=re.sub(' [3] ','3',text)
        text=re.sub(' [4] ','4',text)
        text=re.sub(' [5] ','5',text)
        text=re.sub(' [6] ','6',text)
        text=re.sub(' [7] ','7',text)
        text=re.sub(' [8] ','8',text)
        text=re.sub(' [9] ','9',text)
        text=re.sub(' [0] ','0',text)
        text=re.sub(' [,] ',', ',text)
        text=re.sub(' [?] ','? ',text)
        text=re.sub(' [!] ','! ',text)
        text=re.sub(' [$] ','$ ',text)
        text=re.sub(' [&] ','& ',text)
        text=re.sub(' [/] ','/ ',text)
        text=re.sub(' [:] ',': ',text)
        text=re.sub(' [;] ','; ',text)
        text=re.sub(' [*] ','* ',text)
        text=re.sub(' [\'] ','\'',text)
        text=re.sub(' [\"] ','\"',text)
        return text

    def call(self,text,config=None):
        input_seq=self.preprocess(text)
        states=self.encoder(input_seq,training=False)
        target_seq=np.zeros((1,1))
        target_seq[:,:]=sequences2ids(['<start>']).numpy()[0][0]
        stop_condition=False
        decoded=[]
        while not stop_condition:
            decoder_outputs,new_states=self.decoder([target_seq,states],training=False)
#             index=tf.argmax(decoder_outputs[:,-1,:],axis=-1).numpy().item()
            index=self.sample(decoder_outputs[0,0,:]).item()
            word=ids2sequences([index])
            if word=='<end> ' or len(decoded)>=max_sequence_length:
                stop_condition=True
            else:
                decoded.append(index)
                target_seq=np.zeros((1,1))
                target_seq[:,:]=index
                states=new_states
        return self.postprocess(ids2sequences(decoded))

chatbot=ChatBot(model.encoder,model.decoder,name='chatbot')
chatbot.summary()
# Out:
# Model: "chatbot_encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, None)]            0
#
#  encoder_embedding (Embeddin  (None, None, 256)        625408
#  g)
#
#  layer_normalization_2 (Laye  (None, None, 256)        512
#  rNormalization)
#
#  encoder_lstm (LSTM)         [(None, None, 256),       525312
#                               (None, 256),
#                               (None, 256)]
#
# =================================================================
# Total params: 1,151,232
# Trainable params: 1,151,232
# Non-trainable params: 0
# _________________________________________________________________
# Model: "chatbot_decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, None)]       0           []
#
#  decoder_embedding (Embedding)  (None, None, 256)    625408      ['input_8[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, None, 256)   512         ['decoder_embedding[0][0]']
#  rmalization)
#
#  input_6 (InputLayer)           [(None, 256)]        0           []
#
#  input_7 (InputLayer)           [(None, 256)]        0           []
#
#  decoder_lstm (LSTM)            [(None, None, 256),  525312      ['layer_normalization_2[1][0]',
#                                  (None, 256),                     'input_6[0][0]',
#                                  (None, 256)]                     'input_7[0][0]']
#
#  decoder_dense (Dense)          (None, None, 2443)   627851      ['decoder_lstm[0][0]']
#
# ==================================================================================================
# Total params: 1,779,083
# Trainable params: 1,779,083
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(chatbot.encoder,to_file='encoder.png',show_shapes=True,show_layer_activations=True)

# %%
tf.keras.utils.plot_model(chatbot.decoder,to_file='decoder.png',show_shapes=True,show_layer_activations=True)

# %% [markdown]
# # Time to Chat

# %%
def print_conversation(texts):
    for text in texts:
        print(f'You: {text}')
        print(f'Bot: {chatbot(text)}')
        print('========================')

# %%
print_conversation([
    'hi',
    'do yo know me?',
    'what is your name?',
    'you are bot?',
    'hi, how are you doing?',
    "i'm pretty good. thanks for asking.",
    "Don't ever be in a hurry",
    '''I'm gonna put some dirt in your eye ''',
    '''You're trash ''',
    '''I've read all your research on nano-technology ''',
    '''You want forgiveness? Get religion''',
    '''While you're using the bathroom, i'll order some food.''',
    '''Wow! that's terrible.''',
    '''We'll be here forever.''',
    '''I need something that's reliable.''',
    '''A speeding car ran a red light, killing the girl.''',
    '''Tomorrow we'll have rice and fish for lunch.''',
    '''I like this restaurant because they give you free bread.'''
])
# Out:
# You: hi
# Bot: we'll have fresh fish for a fireman to catch a foul ball.
# ========================
# You: do yo know me?
# Bot: we'll have a good story for you.
# ========================
# You: what is your name?
# Bot: i have to be there.
# ========================
# You: you are bot?
# Bot: i'm not sure. i'm not a cheater.
# ========================
# You: hi, how are you doing?
# Bot: i'm not sure.
# ========================
# You: i'm pretty good. thanks for asking.
# Bot: no problem. i'll give you my nose a lot.
# ========================
# You: Don't ever be in a hurry
# Bot: it's not a good driver, not you're a good deal.
# ========================
# You: I'm gonna put some dirt in your eye
# Bot: that's a good idea.
# ========================
# You: You're trash
# Bot: i've never been a lot of fun.
# ========================
# You: I've read all your research on nano-technology
# Bot: i don't know. i think i'm average.
# ========================
# You: You want forgiveness? Get religion
# Bot: i'm going to be a teacher.
# ========================
# You: While you're using the bathroom, i'll order some food.
# Bot: don't ever be in a hurry when you're sick.
# ========================
# You: Wow! that's terrible.
# Bot: yes, it is.
# ========================
# You: We'll be here forever.
# Bot: do you want the waiter'clean the bus every day?
# ========================
# You: I need something that's reliable.
# Bot: you'd better try them on first.
# ========================
# You: A speeding car ran a red light, killing the girl.
# Bot: what happened to the other student?
# ========================
# You: Tomorrow we'll have rice and fish for lunch.
# Bot: i don't know. maybe i was born.
# ========================
# You: I like this restaurant because they give you free bread.
# Bot: well, i want to go to the movies instead.
# ========================
